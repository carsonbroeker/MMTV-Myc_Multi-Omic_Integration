# %%
# library & dataset
import numpy as np
from scipy import stats
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
df = pd.read_excel("Myc_Pairplot_Input_C6.xlsx")

#plt.rcParams["figure.figsize"] = (20,3)


def corrfunc(x, y, **kws):
    (r, p) = pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f} ".format(r),
                xy=(.1, .9), xycoords=ax.transAxes)
    ax.annotate("p = {:.3f}".format(p),
                xy=(.1, .11), xycoords=ax.transAxes)

# left
c6 = sns.pairplot(df, kind="scatter", 
                  hue="Histology", 
                  height=5,
                  aspect=5,
                  markers=["o", "s", "D"], 
                  palette=["blue","#f0e007","green"], 
                  corner=False, 
                  plot_kws=dict(edgecolor="black"))
for ax in c6.axes.flatten():
    # rotate x axis labels
    ax.set_xlabel(ax.get_xlabel(), rotation = 0)
    # rotate y axis labels
    ax.set_ylabel(ax.get_ylabel(), rotation = 90, va="bottom")
    # set y labels alignment
    ax.yaxis.get_label().set_horizontalalignment('right')
xlabels,ylabels = ['BRCA1_DN.\nV1_UP',
 'KRAS.LUNG_UP.\nV1_UP',
 'PKCA_DN.\nV1_UP'],['BRCA1_DN.V1_UP',
 'KRAS.LUNG_UP.V1_UP',
 'PKCA_DN.V1_UP']
c6.map_upper(sns.kdeplot)
#c6._legend.remove()
c6.axes[0,0].set_xlim((-4700,-2700))
c6.axes[0,0].set_ylim((-4700,-2700))
c6.axes[1,1].set_xlim((-3999,-1400))
c6.axes[1,1].set_ylim((-3999,-1400))
c6.axes[2,2].set_xlim((-4200,-2500))
c6.axes[2,2].set_ylim((-4200,-2500))

#c6.map_lower(sns.regplot(data=df, x= "BRCA1_DN.V1_UP", y= "PKCA_DN.V1_UP", ax=[0,0])

#c6.map_lower(sns.regplot, lowess=False, scatter_kws={'alpha':0.15}, line_kws={'color': 'red'})
#c6.map_lower(sns.regplot(data=df, x="BRCA1_DN.V1_UP", y="KRAS.LUNG_UP.V1_UP"))
#c6.axes[2,0].remove()
#c6.axes[2,1].remove()

#c6.map_lower(corrfunc)

#for ax in c6.axes[-1,:]:
    #xlabel = ax.xaxis.get_label_text()
    #xlabels.append(xlabel)
#for ax in c6.axes[:,0]:
    #ylabel = ax.yaxis.get_label_text()
    #ylabels.append(ylabel)

for i in range(len(xlabels)):
    for j in range(len(ylabels)):
        c6.axes[j,i].xaxis.set_label_text(xlabels[i])
        c6.axes[j,i].yaxis.set_label_text(ylabels[j])

c6._legend.remove()        
fig = c6.fig
fig.set_size_inches(6,6)
fig.savefig("Myc_C6_Pairplot.svg", dpi=1200)

# %%
# library & dataset
import numpy as np
from scipy import stats
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
df = pd.read_excel("Myc_Pairplot_Input_C6.xlsx")

#plt.rcParams["figure.figsize"] = (20,3)

def corrfunc(x, y, **kws):
    (r, p) = pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f} ".format(r),
                xy=(.1, .9), xycoords=ax.transAxes)
    ax.annotate("p = {:.3f}".format(p),
                xy=(.1, .11), xycoords=ax.transAxes)

# left
c6 = sns.pairplot(df, kind="reg", 
                  #hue="Histology", 
                  #markers=["o", "s", "D"], 
                  height=2,
                  aspect=4,
                  palette=["blue","#f0e007","green"], 
                  corner=False, 
                  plot_kws={'line_kws':{'color':'gray'}})
for ax in c6.axes.flatten():
    # rotate x axis labels
    ax.set_xlabel(ax.get_xlabel(), rotation = 0)
    # rotate y axis labels
    ax.set_ylabel(ax.get_ylabel(), rotation = 90, va="bottom")
    # set y labels alignment
    ax.yaxis.get_label().set_horizontalalignment('right')
xlabels,ylabels = ['BRCA1_DN.\nV1_UP',
 'KRAS.LUNG_UP.\nV1_UP',
 'PKCA_DN.\nV1_UP'],['BRCA1_DN.V1_UP',
 'KRAS.LUNG_UP.V1_UP',
 'PKCA_DN.V1_UP']
#c6.map_upper(sns.kdeplot, levels=4, color=".2")
c6.map_lower(corrfunc)
c6.axes[0,0].set_xlim((-4700,-2700))
c6.axes[0,0].set_ylim((-4700,-2700))
c6.axes[1,1].set_xlim((-3999,-1400))
c6.axes[1,1].set_ylim((-3999,-1400))
c6.axes[2,2].set_xlim((-4200,-2500))
c6.axes[2,2].set_ylim((-4200,-2500))

#for ax in c6.axes[-1,:]:
    #xlabel = ax.xaxis.get_label_text()
    #xlabels.append(xlabel)
#for ax in c6.axes[:,0]:
    #ylabel = ax.yaxis.get_label_text()
    #ylabels.append(ylabel)

for i in range(len(xlabels)):
    for j in range(len(ylabels)):
        c6.axes[j,i].xaxis.set_label_text(xlabels[i])
        c6.axes[j,i].yaxis.set_label_text(ylabels[j])


fig = c6.fig
fig.set_size_inches(6,6)
fig.savefig("Myc_C6_Pairplot_reg_line.svg", dpi=1200)

# %%
# library & dataset
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df = pd.read_excel("Myc_Pairplot_Input_C1.xlsx")
df
# left
c1 = sns.pairplot(df, kind="scatter", hue="Histology", markers=["o", "s", "D"], palette=["blue","#f0e007","green"], corner=False)
fig = c1.fig
fig.savefig("Myc_C1_Pairplot.svg", dpi=1200)
plt.show()

# %%
# library & dataset
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


    
df = pd.read_excel("Myc_Pairplot_Input_C2.xlsx")
df
# left
c6 = sns.pairplot(df, kind="scatter", hue="Histology", markers=["o", "s", "D"], palette=["blue","#f0e007","green"], plot_kws=dict(edgecolor="black"), corner=False)
for ax in c6.axes.flatten():
    # rotate x axis labels
    ax.set_xlabel(ax.get_xlabel())
    # rotate y axis labels
    ax.set_ylabel(ax.get_ylabel())
    # set y labels alignment
    ax.yaxis.get_label().set_horizontalalignment('right')
xlabels,ylabels = ['RUNX1T1_FUSION',
 'MIKKELSEN_MEF_HCP',
 'ACTIVATION_MMPs'],['RUNX1T1_FUSION',
 'MIKKELSEN_MEF_HCP',
 'ACTIVATION_MMPs']

c6.map_upper(sns.kdeplot)
c6.axes[0,0].set_xlim((-5000,1600))
c6.axes[0,0].set_ylim((-5000,1600))
c6.axes[1,1].set_xlim((-4900,-3900))
c6.axes[1,1].set_ylim((-4900,-3900))
c6.axes[2,2].set_xlim((-4999,1500))
c6.axes[2,2].set_ylim((-4999,1500))
#for ax in c6.axes[-1,:]:
    #xlabel = ax.xaxis.get_label_text()
    #xlabels.append(xlabel)
#for ax in c6.axes[:,0]:
    #ylabel = ax.yaxis.get_label_text()
    #ylabels.append(ylabel)

for i in range(len(xlabels)):
    for j in range(len(ylabels)):
        c6.axes[j,i].xaxis.set_label_text(xlabels[i])
        c6.axes[j,i].yaxis.set_label_text(ylabels[j])
fig = c6.fig
fig.set_size_inches(6,6)
fig.savefig("Myc_C2_Pairplot.svg", dpi=1200)

# %%
# library & dataset
import numpy as np
from scipy import stats
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

def corrfunc(x, y, **kws):
    (r, p) = pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f} ".format(r),
                xy=(.1, .9), xycoords=ax.transAxes)
    ax.annotate("p = {:.3f}".format(p),
                xy=(.1, .11), xycoords=ax.transAxes)
    
df = pd.read_excel("Myc_Pairplot_Input_C2.xlsx")
df
# left
c6 = sns.pairplot(df, kind="reg", 
                  #hue="Histology", 
                  #markers=["o", "s", "D"], 
                  palette=["blue","#f0e007","green"], 
                  corner=False,
                  plot_kws={'line_kws':{'color':'gray'}})
for ax in c6.axes.flatten():
    # rotate x axis labels
    ax.set_xlabel(ax.get_xlabel())
    # rotate y axis labels
    ax.set_ylabel(ax.get_ylabel())
    # set y labels alignment
    ax.yaxis.get_label().set_horizontalalignment('right')
xlabels,ylabels = ['RUNX1T1_FUSION',
 'MIKKELSEN_MEF_HCP',
 'ACTIVATION_MMPs'],['RUNX1T1_FUSION',
 'MIKKELSEN_MEF_HCP',
 'ACTIVATION_MMPs']
c6.map_lower(corrfunc)
c6.map_upper(sns.kdeplot)
c6.axes[0,0].set_xlim((-5000,1600))
c6.axes[0,0].set_ylim((-5000,1600))
c6.axes[1,1].set_xlim((-4900,-3900))
c6.axes[1,1].set_ylim((-4900,-3900))
c6.axes[2,2].set_xlim((-4999,1500))
c6.axes[2,2].set_ylim((-4999,1500))
#for ax in c6.axes[-1,:]:
    #xlabel = ax.xaxis.get_label_text()
    #xlabels.append(xlabel)
#for ax in c6.axes[:,0]:
    #ylabel = ax.yaxis.get_label_text()
    #ylabels.append(ylabel)

for i in range(len(xlabels)):
    for j in range(len(ylabels)):
        c6.axes[j,i].xaxis.set_label_text(xlabels[i])
        c6.axes[j,i].yaxis.set_label_text(ylabels[j])
fig = c6.fig
fig.set_size_inches(6,6)
fig.savefig("Myc_C2_Pairplot_regline.svg", dpi=1200)
