# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

conf = np.array([(188,0,2,0,12,1),(7,46,0,1,11,0),(2,1,39,14,1,3),(1,5,5,48,0,1),(14,5,0,0,119,0),(16,0,3,0,0,23)])

fig, ax = plt.rcParams["figure.figsize"] = (4,3.5)
sns.heatmap(conf, annot=True, cmap='magma', fmt='g',
           xticklabels=['LumA','Her2','Claudin-low','Basal','LumB','Normal'],
           yticklabels=['LumA','Her2','Claudin-low','Basal','LumB','Normal'])

plt.xticks(rotation=45, ha="right", fontweight='normal')
plt.yticks(fontweight='normal')
plt.xlabel("Predicted Class", fontweight='bold')
plt.ylabel("True Class", fontweight='bold')
plt.savefig("Confusion_Matrix_PAM50_Subtyping.svg", dpi=1200)
